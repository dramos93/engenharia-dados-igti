# %% [markdown]
# 1. Extrair, de maneira progrmática os dados do ENEM 2019.

# %%
import pandas as pd
import numpy as np
import zipfile
import requests
from io import BytesIO
import os

# %%
os.makedirs('./enade2019', exist_ok=True)

# %%
url = "http://download.inep.gov.br/microdados/Enade_Microdados/microdados_enade_2019.zip"

filebytes = BytesIO(
    requests.get(url).content
)

myzip = zipfile.ZipFile(filebytes)
myzip.extractall("./enade2019")

# %%
enade2019 = pd.read_csv(
    './enade2019/microdados_enade_2019/2019/3.DADOS/microdados_enade_2019.txt',
    sep=";", decimal=","
)

# %%
enade2019
# Out:
#         NU_ANO  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  CO_CURSO  \
# 0         2019       1       10002       10028      5710         3
# 1         2019       1       10002       10028      5710         3
# 2         2019       1       10002       10028      5710         3
# 3         2019       1       10002       10028      5710         3
# 4         2019       1       10002       10028      5710         3
# ...        ...     ...         ...         ...       ...       ...
# 433925    2019    3948       10008       10022        95   5001378
# 433926    2019    3948       10008       10022        95   5001378
# 433927    2019    3948       10008       10022        95   5001378
# 433928    2019    3948       10008       10022        95   5001378
# 433929    2019    3948       10008       10022        95   5001378
#
#         CO_MODALIDADE  CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO  ...  \
# 0                   1         5103403           51                5  ...
# ...

# %% [markdown]
# 2. Filtrar apenas os alunos do estado de Minas Gerais

# %%
#CO_UF_CURSO: MG = 31
enadeMG2019 = enade2019.loc[
    enade2019.CO_UF_CURSO == 31
]

# %%
enadeMG2019
# Out:
#         NU_ANO  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  CO_CURSO  \
# 2346      2019       6       10002       10028      5710       586
# 2347      2019       6       10002       10028      5710       586
# 2348      2019       6       10002       10028      5710       586
# 2349      2019       6       10002       10028      5710       586
# 2350      2019       6       10002       10028      5710       586
# ...        ...     ...         ...         ...       ...       ...
# 433286    2019     576          93       10028         6   5001168
# 433287    2019     576          93       10028         6   5001168
# 433288    2019     576          93       10028         6   5001168
# 433289    2019     576          93       10028         6   5001168
# 433290    2019     576          93       10028         6   5001168
#
#         CO_MODALIDADE  CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO  ...  \
# 2346                1         3146107           31                3  ...
# ...

# %% [markdown]
# 3. Salvar um arquivo CSV com os dados já limpos em seu computador

# %%
enadeMG2019.to_csv("./enadeMG2019.csv", sep=";", decimal=",")

# %% [markdown]
# 4. Escrever os dados numa tabela em uma base de dados de sua escolha (MySQL, PostgreSQL, SQL Server etc)

# %%
# ingestão de enadeMG2019 no sql

import pyodbc
import sqlalchemy

# %%
sqlalchemy.__version__
# Out:
# '1.3.18'

# %%
#ingestão
enadeMG2019.to_sql("enade", con=engine, index=False, if_exists="append")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...
