# %% [markdown]
# ## Importar biblioteca pymongo

# %%
#!pip install pymongo
from pymongo import MongoClient

# %%
client = MongoClient('mongodb+srv://unicluster.ixhvw.mongodb.net', username="estudante_igti", password="SRwkJTDz2nA28ME9")

# %%
client
# Out:
# MongoClient(host=['unicluster-shard-00-00.ixhvw.mongodb.net:27017', 'unicluster-shard-00-01.ixhvw.mongodb.net:27017', 'unicluster-shard-00-02.ixhvw.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-5wtvta-shard-0', ssl=True)

# %% [markdown]
# ## Verificando conexão existente

# %%
db = client.ibge
collection = db.pnadc20203

# %%
import pandas as pd

# %%
df_init = pd.DataFrame(list(collection.find()))

# %%
df_init
# Out:
#                              _id   ano  trimestre         uf    sexo  idade  \
# 0       600ce0685daa95c6616007ac  2020          3       Acre  Mulher     62
# 1       600ce0685daa95c6616007ad  2020          3       Acre   Homem      7
# 2       600ce0685daa95c6616007ae  2020          3       Acre  Mulher     42
# 3       600ce0685daa95c6616007af  2020          3       Acre   Homem     47
# 4       600ce0685daa95c6616007b0  2020          3       Acre   Homem     11
# ...                          ...   ...        ...        ...     ...    ...
# 368205  600ce06a5daa95c66165a5f9  2020          3  Tocantins  Mulher     63
# 368206  600ce06a5daa95c66165a5fa  2020          3  Tocantins   Homem     46
# 368207  600ce06a5daa95c66165a5fb  2020          3  Tocantins  Mulher     44
# 368208  600ce06a5daa95c66165a5fc  2020          3  Tocantins  Mulher     27
# 368209  600ce06a5daa95c66165a5fd  2020          3  Tocantins  Mulher     19
#
#            cor graduacao                               trab  \
# 0        Parda      None  Pessoas fora da força de trabalho
# 1        Parda      None                               None
# 2        Preta      None       Pessoas na força de trabalho
# 3        Preta      None       Pessoas na força de trabalho
# 4        Preta      None                               None
# ...        ...       ...                                ...
# 368205  Branca      None  Pessoas fora da força de trabalho
# 368206   Parda      None       Pessoas na força de trabalho
# 368207   Parda      None       Pessoas na força de trabalho
# 368208   Parda      None       Pessoas na força de trabalho
# 368209   Parda       Não  Pessoas fora da força de trabalho
#
#                        ocup   renda  horastrab  anosesco
# 0                      None     NaN        NaN       0.0
# 1                      None     NaN        NaN       1.0
# 2       Pessoas desocupadas     NaN        NaN      12.0
# 3          Pessoas ocupadas  1000.0       30.0      10.0
# 4                      None     NaN        NaN       5.0
# ...                     ...     ...        ...       ...
# 368205                 None     NaN        NaN      12.0
# 368206     Pessoas ocupadas  3000.0       40.0      12.0
# 368207     Pessoas ocupadas  1500.0       44.0      12.0
# 368208     Pessoas ocupadas  1045.0       40.0      14.0
# 368209                 None     NaN        NaN      12.0
#
# [368210 rows x 13 columns]

# %%
type(collection)
# Out:
# pymongo.collection.Collection
