# %% [markdown]
# # Extract Tweets

# %%
# !pip install tweepy datetime

# %% [markdown]
# ## Play!

# %%
# !python get_tweets.py

# %% [markdown]
# # Entendendo a estrutura do JSON

# %%
import json

# %%
# Abrir o arquivo de tweets e les as linhas
with open('collected_tweets_2021-02-01-14-59-34.txt', 'r') as file:
    tweets = file.readlines()

# %%
tweets[7]
# Out:
# '"{\\"created_at\\":\\"Mon Feb 01 17:59:30 +0000 2021\\",\\"id\\":1356301162966876160,\\"id_str\\":\\"1356301162966876160\\",\\"text\\":\\"RT @charliekirk11: The left would rather give Stacey Abrams the Nobel Peace Prize for flipping Georgia blue than Donald Trump for bringing\\\\u2026\\",\\"source\\":\\"\\\\u003ca href=\\\\\\"http:\\\\/\\\\/twitter.com\\\\/download\\\\/android\\\\\\" rel=\\\\\\"nofollow\\\\\\"\\\\u003eTwitter for Android\\\\u003c\\\\/a\\\\u003e\\",\\"truncated\\":false,\\"in_reply_to_status_id\\":null,\\"in_reply_to_status_id_str\\":null,\\"in_reply_to_user_id\\":null,\\"in_reply_to_user_id_str\\":null,\\"in_reply_to_screen_name\\":null,\\"user\\":{\\"id\\":883003959941746688,\\"id_str\\":\\"883003959941746688\\",\\"name\\":\\"Fred-Eau Claire, WI\\",\\"screen_name\\":\\"LocoMan54345595\\",\\"location\\":\\"Eau Claire, WI\\",\\"url\\":null,\\"description\\":\\"Before: Ex-con, former member of a Motocycle Club. Now:  Proud Native American, follower of Christ Jesus and
# ...

# %%
#fazendo o parse to tweet para um formato json e exportar arquivo
with open('tweet.json', 'w') as f:
    json.dump(
        json.loads( json.loads(tweets[0])),
        f
    )

# %%
type (
    json.loads(
        json.loads(tweets[0])
    )
)
# Out:
# dict

# %%
json.loads(
        json.loads(tweets[0])
    )
# Out:
# {'created_at': 'Mon Feb 01 17:59:30 +0000 2021',
#  'id': 1356301162492919814,
#  'id_str': '1356301162492919814',
#  'text': 'RT @OANN: MSNBC condemns ‘violence’, but urges ‘drone strike’ on President Trump - https://t.co/GPwn9zYlDl #OANN https://t.co/Ft3hdGsE6T',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1289573055644274688,
#   'id_str': '1289573055644274688',
#   'name': 'Jeff Michael',
#   'screen_name': 'jeff_michael03',
#   'location': 'United States',
#   'url': None,
#   'description': 'USMC GWOT Combat Veteran - Patriot - #Bitcoin',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 596,
#   'friends_count': 470,
#   'listed_count': 1,
# ...

# %%
parsed_tweets = [json.loads(json.loads(i)) for i in tweets]

# %%
len(parsed_tweets)
# Out:
# 331

# %% [markdown]
# # Acessando as chaves do JSON (dicionário)

# %%
firsttweet = parsed_tweets[8]
firsttweet
# Out:
# {'created_at': 'Mon Feb 01 17:59:30 +0000 2021',
#  'id': 1356301162958479367,
#  'id_str': '1356301162958479367',
#  'text': 'RT @TrumpWarRoom: Former solicitor general of the United States Ken Starr highlights why Democrats can’t  impeach former President Trump.…',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 395491775,
#   'id_str': '395491775',
#   'name': 'P. L.',
#   'screen_name': 'PL14',
#   'location': 'USA',
#   'url': None,
#   'description': 'I want the world to be better. I will retweet news updates, comments or positive images that are important. No DMs plz but thanks for all follows!',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 1482,
# ...

# %%
firsttweet.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])

# %%
list(firsttweet.items())
# Out:
# [('created_at', 'Mon Feb 01 17:59:30 +0000 2021'),
#  ('id', 1356301162958479367),
#  ('id_str', '1356301162958479367'),
#  ('text',
#   'RT @TrumpWarRoom: Former solicitor general of the United States Ken Starr highlights why Democrats can’t  impeach former President Trump.…'),
#  ('source',
#   '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'),
#  ('truncated', False),
#  ('in_reply_to_status_id', None),
#  ('in_reply_to_status_id_str', None),
#  ('in_reply_to_user_id', None),
#  ('in_reply_to_user_id_str', None),
#  ('in_reply_to_screen_name', None),
#  ('user',
#   {'id': 395491775,
#    'id_str': '395491775',
#    'name': 'P. L.',
#    'screen_name': 'PL14',
#    'location': 'USA',
#    'url': None,
#    'description': 'I want the world to be better. I will retweet news updates, comments or positive images that are important. No DMs plz but thanks for all follows!',
#    'translator_type': 'none',
#    'protected': False,
# ...

# %% [markdown]
# # Transformar os tweets em uma estrutura analisável

# %%
import pandas as pd

# %%
teste = pd.DataFrame(firsttweet)
teste
#Esse não funciona
# Out:
#                                    created_at                   id  \
# id             Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
# id_str         Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
# name           Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
# screen_name    Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
# location       Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
# ...                                       ...                  ...
# filter_level   Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
# hashtags       Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
# urls           Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
# user_mentions  Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
# symbols        Mon Feb 01 17:59:30 +0000 2021  1356301162958479367
#
#                             id_str  \
# id             1356301162958479367
# id_str         1356301162958479367
# name           1356301162958479367
# ...

# %%
teste.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'quote_count',
#        'reply_count', 'retweet_count', 'favorite_count', 'entities',
#        'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
df_tratado = pd.DataFrame(firsttweet).reset_index(drop=True).iloc[:1]
len(df_tratado.columns)
# Out:
# 28

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'quote_count',
#        'reply_count', 'retweet_count', 'favorite_count', 'entities',
#        'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
df_tratado.drop(columns=['is_quote_status','quote_count','reply_count','retweet_count','favorite_count','favorited',
                         'retweeted','user','entities','retweeted_status'], inplace=True, errors='ignore')

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'geo', 'coordinates', 'place',
#        'contributors', 'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
display(df_tratado)
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Feb 01 17:59:30 +0000 2021  1356301162958479367  1356301162958479367
#
#                                                 text  \
# 0  RT @TrumpWarRoom: Former solicitor general of ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/android" ...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str in_reply_to_screen_name   geo coordinates place  \
# 0                    None                    None  None        None  None
#
#   contributors filter_level lang   timestamp_ms
# 0         None          low   en  1612202370763

# %%
parsed_tweets[8]['entities']['user_mentions']
# Out:
# [{'screen_name': 'TrumpWarRoom',
#   'name': 'Trump War Room',
#   'id': 1108472017144201216,
#   'id_str': '1108472017144201216',
#   'indices': [3, 16]}]

# %%
df_tratado['user_id'] = firsttweet['user']['id']
df_tratado['user_id_str'] = firsttweet['user']["id_str"]
df_tratado['user_screen_name'] = firsttweet['user']["screen_name"]
df_tratado['user_location'] = firsttweet['user']["location"]
df_tratado['user_description'] = firsttweet['user']["description"]
df_tratado['user_protected'] = firsttweet['user']["protected"]
df_tratado['user_verified'] = firsttweet['user']["verified"]
df_tratado['user_followers_count'] = firsttweet['user']["followers_count"]
df_tratado['user_friends_count'] = firsttweet['user']["friends_count"]
df_tratado['user_created_at'] = firsttweet['user']["created_at"]

# %%
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Feb 01 17:59:30 +0000 2021  1356301162958479367  1356301162958479367
#
#                                                 text  \
# 0  RT @TrumpWarRoom: Former solicitor general of ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/android" ...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...    user_id user_id_str user_screen_name  \
# 0                    None  ...  395491775   395491775             PL14
#
#   user_location                                   user_description  \
# 0           USA  I want the world to be better. I will retweet ...
#
#   user_protected user_verified user_followers_count  user_friends_count  \
# ...

# %%
# Entidades
firsttweet['entities']
# Out:
# {'hashtags': [],
#  'urls': [],
#  'user_mentions': [{'screen_name': 'TrumpWarRoom',
#    'name': 'Trump War Room',
#    'id': 1108472017144201216,
#    'id_str': '1108472017144201216',
#    'indices': [3, 16]}],
#  'symbols': []}

# %%
# user_mentions 
user_mentions = [] 

for i in range(len(firsttweet['entities']['user_mentions'])):
    dicionariobase = firsttweet['entities']['user_mentions'][i].copy()
    dicionariobase.pop('indices', None)
    df = pd.DataFrame(dicionariobase, index=[0])
    df = df.rename(columns={
        'screen_name' : 'entities_screen_name',
        'name' : 'entities_name',
        'id' : 'entities_id',
        'id_str' : 'entities_id_str'
    })
    user_mentions.append(df)
    
display(user_mentions)
# Out:
# [  entities_screen_name   entities_name          entities_id  \
#  0         TrumpWarRoom  Trump War Room  1108472017144201216
#
#         entities_id_str
#  0  1108472017144201216  ]

# %%
user_mentions
# Out:
# [  entities_screen_name   entities_name          entities_id  \
#  0         TrumpWarRoom  Trump War Room  1108472017144201216
#
#         entities_id_str
#  0  1108472017144201216  ]

# %%
dfs = []
for i in user_mentions:
    dfs.append(
        pd.concat([df_tratado.copy(),i], axis=1)
    )

# %%
pd.concat(dfs, ignore_index=True)
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Feb 01 17:59:30 +0000 2021  1356301162958479367  1356301162958479367
#
#                                                 text  \
# 0  RT @TrumpWarRoom: Former solicitor general of ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/android" ...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...  \
# 0                    None  ...
#
#                                     user_description user_protected  \
# 0  I want the world to be better. I will retweet ...          False
#
#   user_verified user_followers_count user_friends_count  \
# 0         False                 1482               3001
#
#                   user_created_at entities_screen_name   entities_name  \
# ...

# %%
parsed_tweets[3]['entities']
# Out:
# {'hashtags': [],
#  'urls': [{'url': 'https://t.co/jJVPAREyKe',
#    'expanded_url': 'https://twitter.com/i/web/status/1356301162706825218',
#    'display_url': 'twitter.com/i/web/status/1…',
#    'indices': [112, 135]}],
#  'user_mentions': [{'screen_name': 'JimVandeHei',
#    'name': 'Jim VandeHei',
#    'id': 244212645,
#    'id_str': '244212645',
#    'indices': [0, 12]},
#   {'screen_name': 'MarkLandler',
#    'name': 'Mark Landler',
#    'id': 120233868,
#    'id_str': '120233868',
#    'indices': [13, 25]},
#   {'screen_name': 'katierogers',
#    'name': 'Katie Rogers',
#    'id': 14116915,
#    'id_str': '14116915',
#    'indices': [26, 38]},
#   {'screen_name': 'patrickhealynyt',
#    'name': 'Patrick Healy',
#    'id': 139870125,
#    'id_str': '139870125',
#    'indices': [39, 55]},
#   {'screen_name': 'JonLemire',
#    'name': 'Jonathan Lemire',
#    'id': 182398325,
#    'id_str': '182398325',
#    'indices': [56, 66]},
#   {'screen_name': 'shearm',
# ...

# %% [markdown]
# Vamos criar uma função que faz todo o tratamento do tweet e converte para um dataframe pandas

# %%
def tweet_para_df(tweet):
    try:
        #pegar o tweet 
        df_tratado = pd.DataFrame(tweet).reset_index(drop=True).iloc[:1]
        #dropar as colunas que não precisamos
        df_tratado.drop(columns=['is_quote_status','quote_count','reply_count','retweet_count','favorite_count','favorited',
                             'retweeted','user','entities', 'retweeted_status', 'self'
                                ], inplace=True,errors='ignore')
        #inplace troca o df_tratado, não precisando passar df_trata = df_tratado.drop....
        #acrescentar variáveis do usuário do tweet, isso estava num array interno
        df_tratado['user_id'] = tweet['user']['id']
        df_tratado['user_id_str'] = tweet['user']["id_str"]
        df_tratado['user_screen_name'] = tweet['user']["screen_name"]
        df_tratado['user_location'] = tweet['user']["location"]
        df_tratado['user_description'] = tweet['user']["description"]
        df_tratado['user_protected'] = tweet['user']["protected"]
        df_tratado['user_verified'] = tweet['user']["verified"]
        df_tratado['user_followers_count'] = tweet['user']["followers_count"]
        df_tratado['user_friends_count'] = tweet['user']["friends_count"]
        df_tratado['user_created_at'] = tweet['user']["created_at"]
        #Acrescentar os usuários mencionados, df intermediário, para jogar no principal
        user_mentions = []

        for i in range(len(tweet['entities']['user_mentions'])):
            dicionariobase = tweet['entities']['user_mentions'][i].copy()
            dicionariobase.pop('indices', None)
            df = pd.DataFrame(dicionariobase, index=[0])
            df = df.rename(columns={
                'screen_name' : 'entities_screen_name',
                'name' : 'entities_name',
                'id' : 'entities_id',
                'id_str' : 'entities_id_str'
            })
            user_mentions.append(df)

        #juntar o df intermediário com o df tratado
        dfs = []
        for i in user_mentions:
            dfs.append(
                pd.concat([df_tratado.copy(),i], axis=1)
            )    
        df_final = pd.concat(dfs, ignore_index=True)
    except:
        return None
    return df_final

# %%
display(tweet_para_df(parsed_tweets[5]))
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Feb 01 17:59:30 +0000 2021  1356301162945912832  1356301162945912832
#
#                                                 text  \
# 0  RT @B52Malmet: Donald Trump is a crime against...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/#!/download/ipad" ...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...  \
# 0                    None  ...
#
#                                     user_description user_protected  \
# 0  New democrat, advocate of environmental & glob...          False
#
#   user_verified user_followers_count user_friends_count  \
# 0         False                 3859               3877
#
#                   user_created_at entities_screen_name   entities_name  \
# ...

# %%
# %%time
#só em jupyter %%time
# Vamos iterar e transformar todos os tweets
parseados = [tweet_para_df(tweet) for tweet in parsed_tweets if tweet is not None]
# Out:
# CPU times: user 2.66 s, sys: 2.16 s, total: 4.82 s
# Wall time: 5.59 s

# %%
# Eliminar as posições vazias da lista

#parseados = [i for i in parseados if i is not None]

# %%
t = pd.concat(parseados,ignore_index=True)
t
# Out:
#                          created_at                   id               id_str  \
# 0    Mon Feb 01 17:59:30 +0000 2021  1356301162492919814  1356301162492919814
# 1    Mon Feb 01 17:59:30 +0000 2021  1356301162585194496  1356301162585194496
# 2    Mon Feb 01 17:59:30 +0000 2021  1356301162585194496  1356301162585194496
# 3    Mon Feb 01 17:59:30 +0000 2021  1356301162585194496  1356301162585194496
# 4    Mon Feb 01 17:59:30 +0000 2021  1356301162601873408  1356301162601873408
# ..                              ...                  ...                  ...
# 339  Mon Feb 01 17:59:44 +0000 2021  1356301222421135364  1356301222421135364
# 340  Mon Feb 01 17:59:44 +0000 2021  1356301222421135364  1356301222421135364
# 341  Mon Feb 01 17:59:44 +0000 2021  1356301222593093635  1356301222593093635
# 342  Mon Feb 01 17:59:44 +0000 2021  1356301222593093635  1356301222593093635
# 343  Mon Feb 01 17:59:44 +0000 2021  1356301222593093635  1356301222593093635
#
# ...

# %% [markdown]
# ## Salvando no sql

# %%
import pyodbc
import sqlalchemy

# %%
engine = sqlalchemy.create_engine(
    'mssql+pyodbc://SA:Ubuntu@123@127.0.0.1/twitter?driver=ODBC+Driver+17+for+sql+server',
    isolation_level='AUTOCOMMIT'
)

# %%
from sqlalchemy_utils import database_exists, create_database

if not database_exists(engine.url):
    create_database(engine.url)

# %%
t.to_sql("tweets", con=engine, index=False, if_exists="replace")

# %% [markdown]
# ## Outros Testes

# %%
df1 = pd.DataFrame([[0,1,2,3],[4,5,6,7]], columns=['A','b','C','D'])
df2 = pd.DataFrame([['a','b','c','d','e'],'d e f g h'.split()], columns=['A','b','C','G','H'])
df3 = pd.DataFrame([[8,9,10,11],[12,13,14,15]], columns=['A','b','C','D'])

dfc = pd.concat([df1,df2, df3], ignore_index=True)
dfc
# Out:
#     A   b   C     D    G    H
# 0   0   1   2   3.0  NaN  NaN
# 1   4   5   6   7.0  NaN  NaN
# 2   a   b   c   NaN    d    e
# 3   d   e   f   NaN    g    h
# 4   8   9  10  11.0  NaN  NaN
# 5  12  13  14  15.0  NaN  NaN

# %%
# %%time

#Como manter colunas específicas? df[[arraydascolunasparamanter]]
df = pd.DataFrame({'name':['Daniel', 'Renata', 'Abigail'], 'idade':[27,23,24],'peso':[78,65,58],'sexo':['M','F','F']})
df = df[['name','sexo']]
#df = df.iloc[:,[0,3]] #somente numéricos, nesse caso, coluna 0=name e 3=sexo
#df = df.filter(items =['name','sexo'])
df = df.loc[:,['name','sexo']]
df.columns
#Outra opção é numerar a quantidade: df.iloc[:, 0:2]

#df = df.iloc[:,1:4] # : => seria como de até. ex.: 1:5, nesse caso pegaria pela pelo index da coluna
# Out:
# CPU times: user 823 µs, sys: 6.74 ms, total: 7.57 ms
# Wall time: 15 ms
# Index(['name', 'sexo'], dtype='object')

# %%
df.loc[1:2]
# Out:
#       name sexo
# 1   Renata    F
# 2  Abigail    F

# %%
#brinks

df1 = pd.DataFrame({'nome':['Daniel', 'Abigail', 'Renata', 'Arthur', 'Catarina'],'idade':[27,24,23,2,3], 'id_cidade':[1,2,1,3,3]})
df2 = pd.DataFrame({'id':[1,2,3],'cidade':['Blumenau','São Francisco do Sul','Imbituba']})

pd.concat([df1,df2],ignore_index=True)
# Out:
#        nome  idade  id_cidade   id                cidade
# 0    Daniel   27.0        1.0  NaN                   NaN
# 1   Abigail   24.0        2.0  NaN                   NaN
# 2    Renata   23.0        1.0  NaN                   NaN
# 3    Arthur    2.0        3.0  NaN                   NaN
# 4  Catarina    3.0        3.0  NaN                   NaN
# 5       NaN    NaN        NaN  1.0              Blumenau
# 6       NaN    NaN        NaN  2.0  São Francisco do Sul
# 7       NaN    NaN        NaN  3.0              Imbituba

# %%
pd.merge(df1,df2, left_on='id_cidade', right_on='id')
# Out:
#        nome  idade  id_cidade  id                cidade
# 0    Daniel     27          1   1              Blumenau
# 1    Renata     23          1   1              Blumenau
# 2   Abigail     24          2   2  São Francisco do Sul
# 3    Arthur      2          3   3              Imbituba
# 4  Catarina      3          3   3              Imbituba

# %%
pd.merge(df1,df2, left_on='id_cidade', right_on='id').loc[:,['nome','idade','cidade']]
# Out:
#        nome  idade                cidade
# 0    Daniel     27              Blumenau
# 1    Renata     23              Blumenau
# 2   Abigail     24  São Francisco do Sul
# 3    Arthur      2              Imbituba
# 4  Catarina      3              Imbituba

# %%
pd.merge(df1,df2, left_on='id_cidade', right_on='id').drop(columns=['id','id_cidade'])
# Out:
#        nome  idade                cidade
# 0    Daniel     27              Blumenau
# 1    Renata     23              Blumenau
# 2   Abigail     24  São Francisco do Sul
# 3    Arthur      2              Imbituba
# 4  Catarina      3              Imbituba
